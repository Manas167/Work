# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plt
figsize(12.5, 4)
p = np.linspace(2400, 2500, 50)
plt.plot(p, 13.5/100 + 19.8*np.log(p/2450)/100 + 2*188.7*np.log(p/2450)/100)
plt.show
# Out:
# <function matplotlib.pyplot.show>
