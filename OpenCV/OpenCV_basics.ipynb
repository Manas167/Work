# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('messi.jpg',cv2.IMREAD_COLOR)

kernel = np.ones((5,5),np.float32)/25

blur = cv2.medianBlur(img,5)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img.shape, img.size
# Out:
# ((308L, 450L, 3L), 415800)

# %%
img[:,:,0] = np.zeros((308,450))
plt.subplot(121),plt.imshow(img),plt.title('Change Color')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x672e6a0>,
# ...
#  <matplotlib.text.Text at 0x6a5c320>)

# %%
ball = img[240:280, 330:390]
img[220:260, 100:160] = ball
plt.subplot(121),plt.imshow(img),plt.title('Replac ball')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x6a50198>,
# ...
#  <matplotlib.text.Text at 0x7af1780>)

# %%
b,g,r = cv2.split(img)

# %%
plt.subplot(121),plt.imshow(g),plt.title('Single Color')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x65d6f28>,
# ...
#  <matplotlib.text.Text at 0x7dc8f60>)
